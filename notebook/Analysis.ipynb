# %% [markdown]
# # Importing dataset and functions for the analysis

# %%
import gafam 
from gafam import analysis, data
from gafam.analysis import *

# %% [markdown]
# # Read the properties of each individual tree in a dataframe

# %%
df, error=forest()
# Out:
# ################################################################################
# MTG is  /home/francesco/Projects/UNIMORE/Progetti in corso/Agroforestry Apple/gafam/src/gafam/data/p1.txt
# ERROR: Missing component for vertex 10
# ERROR: Missing component for vertex 21
# ERROR: Missing component for vertex 26
# ERROR: Missing component for vertex 30
# ERROR: Missing component for vertex 35
# ERROR: Missing component for vertex 40
# ERROR: Missing component for vertex 44
# ERROR: Missing component for vertex 55
# ERROR: Missing component for vertex 59
# ERROR: Missing component for vertex 64
# ERROR: Missing component for vertex 68
# ERROR: Missing component for vertex 73
# ERROR: Missing component for vertex 82
# ERROR: Missing component for vertex 204
# ERROR: Missing component for vertex 208
# ERROR: Missing component for vertex 223
# ERROR: Missing component for vertex 239
# ERROR: Missing component for vertex 243
# ERROR: Missing component for vertex 262
# ...

# %%
df
# Out:
#    apple_tree trt NCI  TSA_2018   TSA_2019  L_shoot_V_2018  L_shoot_V_2019  \
# 0           1  ac      3.905707   7.793113              32              11
# 1           3  ac      7.306166  10.752101              32              25
# 2           4  ac      6.834928  11.641564              41              24
# 3           9  ac      4.523893  10.752101              58              56
# 4          12  ac      3.300636   6.157522              47              23
# 5          23  ac      4.154756   5.515459              40               2
# 6          27  ac      3.463606   9.621128              18              16
# 7          28  ac      3.976078   8.814131              45              20
# 8          30  ac      6.157522   8.552986              15              46
# 9          32  ac      3.141593   7.068583              45              47
# 10         34  ac      3.630503   6.605199              37              56
# ...

# %%
# Plot a property at plant scale, such as TSA against treatment

# %%
df.plot.scatter(x="TSA_2018", y=["TSA_2019"])
# Out:
# /home/francesco/Applications/miniconda3/envs/openalea/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='TSA_2018', ylabel='[TSA_2019]'>

# %% [markdown]
# # Read the properties of every branch from each individual tree in a dataframe

# %%
bdf, err = branches()
# Out:
# ################################################################################
# MTG is  /home/francesco/Projects/UNIMORE/Progetti in corso/Agroforestry Apple/gafam/src/gafam/data/p1.txt
# ERROR: Missing component for vertex 10
# ERROR: Missing component for vertex 21
# ERROR: Missing component for vertex 26
# ERROR: Missing component for vertex 30
# ERROR: Missing component for vertex 35
# ERROR: Missing component for vertex 40
# ERROR: Missing component for vertex 44
# ERROR: Missing component for vertex 55
# ERROR: Missing component for vertex 59
# ERROR: Missing component for vertex 64
# ERROR: Missing component for vertex 68
# ERROR: Missing component for vertex 73
# ERROR: Missing component for vertex 82
# ERROR: Missing component for vertex 204
# ERROR: Missing component for vertex 208
# ERROR: Missing component for vertex 223
# ERROR: Missing component for vertex 239
# ERROR: Missing component for vertex 243
# ERROR: Missing component for vertex 262
# ...

# %%
bdf
# Out:
#      apple_tree  BSA_2018  BSA_2019  B_pos    B_dist  B_lgth_2018  \
# 0             1      1.20      1.80      1  0.009709        192.0
# 1             1      0.75      1.00     18  0.174757         11.4
# 2             1      0.75      1.00     19  0.184466         10.0
# 3             1      0.70      1.20     20  0.194175         14.2
# 4             1      1.20      1.75     21  0.203883        165.2
# ...         ...       ...       ...    ...       ...          ...
# 1226        148      0.30      0.65     75  0.833333         14.4
# 1227        148      0.30      0.65     76  0.844444          6.6
# 1228        148      0.00      0.30     82  0.911111          0.0
# 1229        148      0.00      0.30     84  0.933333          0.0
# 1230        148      0.00      0.30     85  0.944444          0.0
#
#       B_lgth_2019  L_shoot_V_2018  L_shoot_V_2018  L_shoot_F_2019  ...  \
# 0           288.0               0               0               6  ...
# ...

# %%
err
# Out:
# [Path('/home/francesco/Projects/UNIMORE/Progetti in corso/Agroforestry Apple/gafam/src/gafam/data/p30.txt')]
